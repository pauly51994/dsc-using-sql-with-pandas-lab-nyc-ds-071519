# %% [markdown]
# # Using SQL with Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll practice using sql statements and the .query() method provided by pandas to manipulate datasets.
#
# ## Objectives
#
# You will be able to:
#
# * Query DataFrames with SQL using the `pandasql` library
# * Query DataFrames by slicing with conditional logic
# * Use the query method to access data
#
# ## The Dataset
#
# In this lab, we'll continue working with the _Titanic Survivors_ Dataset
#
# Begin by importing `pandas` as `pd`, `numpy` as `np`, and `matplotlib.pyplot` as `plt`, and set the appropriate alias for each. Additionally, set `%matplotlib inline`.

# %%
#Your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, read in the data from `titanic.csv` and store it as a DataFrame in `df`. Display the `.head()` to ensure that everything loaded correctly.

# %%
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-51-060f5dd03f0f> in <module>()
# ----> 1 my_data = np.genfromtxt('titanic.csv', delimiter = ',')
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2073             # Raise an exception ?
#    2074             if invalid_raise:
# -> 2075                 raise ValueError(errmsg)
#    2076             # Issue a warning ?
#    2077             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 14 columns instead of 13)
#     Line #3 (got 14 columns instead of 13)
#     Line #4 (got 14 columns instead of 13)
#     Line #5 (got 14 columns instead of 13)
#     Line #6 (got 14 columns instead of 13)
#     Line #7 (got 14 columns instead of 13)
#     Line #8 (got 14 columns instead of 13)
#     Line #9 (got 14 columns instead of 13)
#     Line #10 (got 14 columns instead of 13)
#     Line #11 (got 14 columns instead of 13)
#     Line #12 (got 14 columns instead of 13)
#     Line #13 (got 14 columns instead of 13)
#     Line #14 (got 14 columns instead of 13)
#     Line #15 (got 14 columns instead of 13)
#     Line #16 (got 14 columns instead of 13)
#     Line #17 (got 14 columns instead of 13)
#     Line #18 (got 14 columns instead of 13)
#     Line #19 (got 14 columns instead of 13)
#     Line #20 (got 14 columns instead of 13)
#     Line #21 (got 14 columns instead of 13)
#     Line #22 (got 14 columns instead of 13)
#     Line #23 (got 14 columns instead of 13)
#     Line #24 (got 14 columns instead of 13)
#     Line #25 (got 14 columns instead of 13)
#     Line #26 (got 14 columns instead of 13)
#     Line #27 (got 14 columns instead of 13)
#     Line #28 (got 14 columns instead of 13)
#     Line #29 (got 14 columns instead of 13)
#     Line #30 (got 14 columns instead of 13)
#     Line #31 (got 14 columns instead of 13)
#     Line #32 (got 14 columns instead of 13)
#     Line #33 (got 14 columns instead of 13)
#     Line #34 (got 14 columns instead of 13)
#     Line #35 (got 14 columns instead of 13)
#     Line #36 (got 14 columns instead of 13)
#     Line #37 (got 14 columns instead of 13)
#     Line #38 (got 14 columns instead of 13)
#     Line #39 (got 14 columns instead of 13)
#     Line #40 (got 14 columns instead of 13)
#     Line #41 (got 14 columns instead of 13)
#     Line #42 (got 14 columns instead of 13)
#     Line #43 (got 14 columns instead of 13)
#     Line #44 (got 14 columns instead of 13)
#     Line #45 (got 14 columns instead of 13)
#     Line #46 (got 14 columns instead of 13)
#     Line #47 (got 14 columns instead of 13)
#     Line #48 (got 14 columns instead of 13)
#     Line #49 (got 14 columns instead of 13)
#     Line #50 (got 14 columns instead of 13)
#     Line #51 (got 14 columns instead of 13)
#     Line #52 (got 14 columns instead of 13)
#     Line #53 (got 14 columns instead of 13)
#     Line #54 (got 14 columns instead of 13)
#     Line #55 (got 14 columns instead of 13)
#     Line #56 (got 14 columns instead of 13)
#     Line #57 (got 14 columns instead of 13)
#     Line #58 (got 14 columns instead of 13)
#     Line #59 (got 14 columns instead of 13)
#     Line #60 (got 14 columns instead of 13)
#     Line #61 (got 14 columns instead of 13)
#     Line #62 (got 14 columns instead of 13)
#     Line #63 (got 14 columns instead of 13)
#     Line #64 (got 14 columns instead of 13)
#     Line #65 (got 14 columns instead of 13)
#     Line #66 (got 14 columns instead of 13)
#     Line #67 (got 14 columns instead of 13)
#     Line #68 (got 14 columns instead of 13)
#     Line #69 (got 14 columns instead of 13)
#     Line #70 (got 14 columns instead of 13)
#     Line #71 (got 14 columns instead of 13)
#     Line #72 (got 14 columns instead of 13)
#     Line #73 (got 14 columns instead of 13)
#     Line #74 (got 14 columns instead of 13)
#     Line #75 (got 14 columns instead of 13)
#     Line #76 (got 14 columns instead of 13)
#     Line #77 (got 14 columns instead of 13)
#     Line #78 (got 14 columns instead of 13)
#     Line #79 (got 14 columns instead of 13)
#     Line #80 (got 14 columns instead of 13)
#     Line #81 (got 14 columns instead of 13)
#     Line #82 (got 14 columns instead of 13)
#     Line #83 (got 14 columns instead of 13)
#     Line #84 (got 14 columns instead of 13)
#     Line #85 (got 14 columns instead of 13)
#     Line #86 (got 14 columns instead of 13)
#     Line #87 (got 14 columns instead of 13)
#     Line #88 (got 14 columns instead of 13)
#     Line #89 (got 14 columns instead of 13)
#     Line #90 (got 14 columns instead of 13)
#     Line #91 (got 14 columns instead of 13)
#     Line #92 (got 14 columns instead of 13)
#     Line #93 (got 14 columns instead of 13)
#     Line #94 (got 14 columns instead of 13)
#     Line #95 (got 14 columns instead of 13)
#     Line #96 (got 14 columns instead of 13)
#     Line #97 (got 14 columns instead of 13)
#     Line #98 (got 14 columns instead of 13)
#     Line #99 (got 14 columns instead of 13)
#     Line #100 (got 14 columns instead of 13)
#     Line #101 (got 14 columns instead of 13)
#     Line #102 (got 14 columns instead of 13)
#     Line #103 (got 14 columns instead of 13)
#     Line #104 (got 14 columns instead of 13)
#     Line #105 (got 14 columns instead of 13)
#     Line #106 (got 14 columns instead of 13)
#     Line #107 (got 14 columns instead of 13)
#     Line #108 (got 14 columns instead of 13)
#     Line #109 (got 14 columns instead of 13)
#     Line #110 (got 14 columns instead of 13)
#     Line #111 (got 14 columns instead of 13)
#     Line #112 (got 14 columns instead of 13)
#     Line #113 (got 14 columns instead of 13)
#     Line #114 (got 14 columns instead of 13)
#     Line #115 (got 14 columns instead of 13)
#     Line #116 (got 14 columns instead of 13)
#     Line #117 (got 14 columns instead of 13)
#     Line #118 (got 14 columns instead of 13)
#     Line #119 (got 14 columns instead of 13)
#     Line #120 (got 14 columns instead of 13)
#     Line #121 (got 14 columns instead of 13)
#     Line #122 (got 14 columns instead of 13)
#     Line #123 (got 14 columns instead of 13)
#     Line #124 (got 14 columns instead of 13)
#     Line #125 (got 14 columns instead of 13)
#     Line #126 (got 14 columns instead of 13)
#     Line #127 (got 14 columns instead of 13)
#     Line #128 (got 14 columns instead of 13)
#     Line #129 (got 14 columns instead of 13)
#     Line #130 (got 14 columns instead of 13)
#     Line #131 (got 14 columns instead of 13)
#     Line #132 (got 14 columns instead of 13)
#     Line #133 (got 14 columns instead of 13)
#     Line #134 (got 14 columns instead of 13)
#     Line #135 (got 14 columns instead of 13)
#     Line #136 (got 14 columns instead of 13)
#     Line #137 (got 14 columns instead of 13)
#     Line #138 (got 14 columns instead of 13)
#     Line #139 (got 14 columns instead of 13)
#     Line #140 (got 14 columns instead of 13)
#     Line #141 (got 14 columns instead of 13)
#     Line #142 (got 14 columns instead of 13)
#     Line #143 (got 14 columns instead of 13)
#     Line #144 (got 14 columns instead of 13)
#     Line #145 (got 14 columns instead of 13)
#     Line #146 (got 14 columns instead of 13)
#     Line #147 (got 14 columns instead of 13)
#     Line #148 (got 14 columns instead of 13)
#     Line #149 (got 14 columns instead of 13)
#     Line #150 (got 14 columns instead of 13)
#     Line #151 (got 14 columns instead of 13)
#     Line #152 (got 14 columns instead of 13)
#     Line #153 (got 14 columns instead of 13)
#     Line #154 (got 14 columns instead of 13)
#     Line #155 (got 14 columns instead of 13)
#     Line #156 (got 14 columns instead of 13)
#     Line #157 (got 14 columns instead of 13)
#     Line #158 (got 14 columns instead of 13)
#     Line #159 (got 14 columns instead of 13)
#     Line #160 (got 14 columns instead of 13)
#     Line #161 (got 14 columns instead of 13)
#     Line #162 (got 14 columns instead of 13)
#     Line #163 (got 14 columns instead of 13)
#     Line #164 (got 14 columns instead of 13)
#     Line #165 (got 14 columns instead of 13)
#     Line #166 (got 14 columns instead of 13)
#     Line #167 (got 14 columns instead of 13)
#     Line #168 (got 14 columns instead of 13)
#     Line #169 (got 14 columns instead of 13)
#     Line #170 (got 14 columns instead of 13)
#     Line #171 (got 14 columns instead of 13)
#     Line #172 (got 14 columns instead of 13)
#     Line #173 (got 14 columns instead of 13)
#     Line #174 (got 14 columns instead of 13)
#     Line #175 (got 14 columns instead of 13)
#     Line #176 (got 14 columns instead of 13)
#     Line #177 (got 14 columns instead of 13)
#     Line #178 (got 14 columns instead of 13)
#     Line #179 (got 14 columns instead of 13)
#     Line #180 (got 14 columns instead of 13)
#     Line #181 (got 14 columns instead of 13)
#     Line #182 (got 14 columns instead of 13)
#     Line #183 (got 14 columns instead of 13)
#     Line #184 (got 14 columns instead of 13)
#     Line #185 (got 14 columns instead of 13)
#     Line #186 (got 14 columns instead of 13)
#     Line #187 (got 14 columns instead of 13)
#     Line #188 (got 14 columns instead of 13)
#     Line #189 (got 14 columns instead of 13)
#     Line #190 (got 14 columns instead of 13)
#     Line #191 (got 14 columns instead of 13)
#     Line #192 (got 14 columns instead of 13)
#     Line #193 (got 14 columns instead of 13)
#     Line #194 (got 14 columns instead of 13)
#     Line #195 (got 14 columns instead of 13)
#     Line #196 (got 14 columns instead of 13)
#     Line #197 (got 14 columns instead of 13)
#     Line #198 (got 14 columns instead of 13)
#     Line #199 (got 14 columns instead of 13)
#     Line #200 (got 14 columns instead of 13)
#     Line #201 (got 14 columns instead of 13)
#     Line #202 (got 14 columns instead of 13)
#     Line #203 (got 14 columns instead of 13)
#     Line #204 (got 14 columns instead of 13)
#     Line #205 (got 14 columns instead of 13)
#     Line #206 (got 14 columns instead of 13)
#     Line #207 (got 14 columns instead of 13)
#     Line #208 (got 14 columns instead of 13)
#     Line #209 (got 14 columns instead of 13)
#     Line #210 (got 14 columns instead of 13)
#     Line #211 (got 14 columns instead of 13)
#     Line #212 (got 14 columns instead of 13)
#     Line #213 (got 14 columns instead of 13)
#     Line #214 (got 14 columns instead of 13)
#     Line #215 (got 14 columns instead of 13)
#     Line #216 (got 14 columns instead of 13)
#     Line #217 (got 14 columns instead of 13)
#     Line #218 (got 14 columns instead of 13)
#     Line #219 (got 14 columns instead of 13)
#     Line #220 (got 14 columns instead of 13)
#     Line #221 (got 14 columns instead of 13)
#     Line #222 (got 14 columns instead of 13)
#     Line #223 (got 14 columns instead of 13)
#     Line #224 (got 14 columns instead of 13)
#     Line #225 (got 14 columns instead of 13)
#     Line #226 (got 14 columns instead of 13)
#     Line #227 (got 14 columns instead of 13)
#     Line #228 (got 14 columns instead of 13)
#     Line #229 (got 14 columns instead of 13)
#     Line #230 (got 14 columns instead of 13)
#     Line #231 (got 14 columns instead of 13)
#     Line #232 (got 14 columns instead of 13)
#     Line #233 (got 14 columns instead of 13)
#     Line #234 (got 14 columns instead of 13)
#     Line #235 (got 14 columns instead of 13)
#     Line #236 (got 14 columns instead of 13)
#     Line #237 (got 14 columns instead of 13)
#     Line #238 (got 14 columns instead of 13)
#     Line #239 (got 14 columns instead of 13)
#     Line #240 (got 14 columns instead of 13)
#     Line #241 (got 14 columns instead of 13)
#     Line #242 (got 14 columns instead of 13)
#     Line #243 (got 14 columns instead of 13)
#     Line #244 (got 14 columns instead of 13)
#     Line #245 (got 14 columns instead of 13)
#     Line #246 (got 14 columns instead of 13)
#     Line #247 (got 14 columns instead of 13)
#     Line #248 (got 14 columns instead of 13)
#     Line #249 (got 14 columns instead of 13)
#     Line #250 (got 14 columns instead of 13)
#     Line #251 (got 14 columns instead of 13)
#     Line #252 (got 14 columns instead of 13)
#     Line #253 (got 14 columns instead of 13)
#     Line #254 (got 14 columns instead of 13)
#     Line #255 (got 14 columns instead of 13)
#     Line #256 (got 14 columns instead of 13)
#     Line #257 (got 14 columns instead of 13)
#     Line #258 (got 14 columns instead of 13)
#     Line #259 (got 14 columns instead of 13)
#     Line #260 (got 14 columns instead of 13)
#     Line #261 (got 14 columns instead of 13)
#     Line #262 (got 14 columns instead of 13)
#     Line #263 (got 14 columns instead of 13)
#     Line #264 (got 14 columns instead of 13)
#     Line #265 (got 14 columns instead of 13)
#     Line #266 (got 14 columns instead of 13)
#     Line #267 (got 14 columns instead of 13)
#     Line #268 (got 14 columns instead of 13)
#     Line #269 (got 14 columns instead of 13)
#     Line #270 (got 14 columns instead of 13)
#     Line #271 (got 14 columns instead of 13)
#     Line #272 (got 14 columns instead of 13)
#     Line #273 (got 14 columns instead of 13)
#     Line #274 (got 14 columns instead of 13)
#     Line #275 (got 14 columns instead of 13)
#     Line #276 (got 14 columns instead of 13)
#     Line #277 (got 14 columns instead of 13)
#     Line #278 (got 14 columns instead of 13)
#     Line #279 (got 14 columns instead of 13)
#     Line #280 (got 14 columns instead of 13)
#     Line #281 (got 14 columns instead of 13)
#     Line #282 (got 14 columns instead of 13)
#     Line #283 (got 14 columns instead of 13)
#     Line #284 (got 14 columns instead of 13)
#     Line #285 (got 14 columns instead of 13)
#     Line #286 (got 14 columns instead of 13)
#     Line #287 (got 14 columns instead of 13)
#     Line #288 (got 14 columns instead of 13)
#     Line #289 (got 14 columns instead of 13)
#     Line #290 (got 14 columns instead of 13)
#     Line #291 (got 14 columns instead of 13)
#     Line #292 (got 14 columns instead of 13)
#     Line #293 (got 14 columns instead of 13)
#     Line #294 (got 14 columns instead of 13)
#     Line #295 (got 14 columns instead of 13)
#     Line #296 (got 14 columns instead of 13)
#     Line #297 (got 14 columns instead of 13)
#     Line #298 (got 14 columns instead of 13)
#     Line #299 (got 14 columns instead of 13)
#     Line #300 (got 14 columns instead of 13)
#     Line #301 (got 14 columns instead of 13)
#     Line #302 (got 14 columns instead of 13)
#     Line #303 (got 14 columns instead of 13)
#     Line #304 (got 14 columns instead of 13)
#     Line #305 (got 14 columns instead of 13)
#     Line #306 (got 14 columns instead of 13)
#     Line #307 (got 14 columns instead of 13)
#     Line #308 (got 14 columns instead of 13)
#     Line #309 (got 14 columns instead of 13)
#     Line #310 (got 14 columns instead of 13)
#     Line #311 (got 14 columns instead of 13)
#     Line #312 (got 14 columns instead of 13)
#     Line #313 (got 14 columns instead of 13)
#     Line #314 (got 14 columns instead of 13)
#     Line #315 (got 14 columns instead of 13)
#     Line #316 (got 14 columns instead of 13)
#     Line #317 (got 14 columns instead of 13)
#     Line #318 (got 14 columns instead of 13)
#     Line #319 (got 14 columns instead of 13)
#     Line #320 (got 14 columns instead of 13)
#     Line #321 (got 14 columns instead of 13)
#     Line #322 (got 14 columns instead of 13)
#     Line #323 (got 14 columns instead of 13)
#     Line #324 (got 14 columns instead of 13)
#     Line #325 (got 14 columns instead of 13)
#     Line #326 (got 14 columns instead of 13)
#     Line #327 (got 14 columns instead of 13)
#     Line #328 (got 14 columns instead of 13)
#     Line #329 (got 14 columns instead of 13)
#     Line #330 (got 14 columns instead of 13)
#     Line #331 (got 14 columns instead of 13)
#     Line #332 (got 14 columns instead of 13)
#     Line #333 (got 14 columns instead of 13)
#     Line #334 (got 14 columns instead of 13)
#     Line #335 (got 14 columns instead of 13)
#     Line #336 (got 14 columns instead of 13)
#     Line #337 (got 14 columns instead of 13)
#     Line #338 (got 14 columns instead of 13)
#     Line #339 (got 14 columns instead of 13)
#     Line #340 (got 14 columns instead of 13)
#     Line #341 (got 14 columns instead of 13)
#     Line #342 (got 14 columns instead of 13)
#     Line #343 (got 14 columns instead of 13)
#     Line #344 (got 14 columns instead of 13)
#     Line #345 (got 14 columns instead of 13)
#     Line #346 (got 14 columns instead of 13)
#     Line #347 (got 14 columns instead of 13)
#     Line #348 (got 14 columns instead of 13)
#     Line #349 (got 14 columns instead of 13)
#     Line #350 (got 14 columns instead of 13)
#     Line #351 (got 14 columns instead of 13)
#     Line #352 (got 14 columns instead of 13)
#     Line #353 (got 14 columns instead of 13)
#     Line #354 (got 14 columns instead of 13)
#     Line #355 (got 14 columns instead of 13)
#     Line #356 (got 14 columns instead of 13)
#     Line #357 (got 14 columns instead of 13)
#     Line #358 (got 14 columns instead of 13)
#     Line #359 (got 14 columns instead of 13)
#     Line #360 (got 14 columns instead of 13)
#     Line #361 (got 14 columns instead of 13)
#     Line #362 (got 14 columns instead of 13)
#     Line #363 (got 14 columns instead of 13)
#     Line #364 (got 14 columns instead of 13)
#     Line #365 (got 14 columns instead of 13)
#     Line #366 (got 14 columns instead of 13)
#     Line #367 (got 14 columns instead of 13)
#     Line #368 (got 14 columns instead of 13)
#     Line #369 (got 14 columns instead of 13)
#     Line #370 (got 14 columns instead of 13)
#     Line #371 (got 14 columns instead of 13)
#     Line #372 (got 14 columns instead of 13)
#     Line #373 (got 14 columns instead of 13)
#     Line #374 (got 14 columns instead of 13)
#     Line #375 (got 14 columns instead of 13)
#     Line #376 (got 14 columns instead of 13)
#     Line #377 (got 14 columns instead of 13)
#     Line #378 (got 14 columns instead of 13)
#     Line #379 (got 14 columns instead of 13)
#     Line #380 (got 14 columns instead of 13)
#     Line #381 (got 14 columns instead of 13)
#     Line #382 (got 14 columns instead of 13)
#     Line #383 (got 14 columns instead of 13)
#     Line #384 (got 14 columns instead of 13)
#     Line #385 (got 14 columns instead of 13)
#     Line #386 (got 14 columns instead of 13)
#     Line #387 (got 14 columns instead of 13)
#     Line #388 (got 14 columns instead of 13)
#     Line #389 (got 14 columns instead of 13)
#     Line #390 (got 14 columns instead of 13)
#     Line #391 (got 14 columns instead of 13)
#     Line #392 (got 14 columns instead of 13)
#     Line #393 (got 14 columns instead of 13)
#     Line #394 (got 14 columns instead of 13)
#     Line #395 (got 14 columns instead of 13)
#     Line #396 (got 14 columns instead of 13)
#     Line #397 (got 14 columns instead of 13)
#     Line #398 (got 14 columns instead of 13)
#     Line #399 (got 14 columns instead of 13)
#     Line #400 (got 14 columns instead of 13)
#     Line #401 (got 14 columns instead of 13)
#     Line #402 (got 14 columns instead of 13)
#     Line #403 (got 14 columns instead of 13)
#     Line #404 (got 14 columns instead of 13)
#     Line #405 (got 14 columns instead of 13)
#     Line #406 (got 14 columns instead of 13)
#     Line #407 (got 14 columns instead of 13)
#     Line #408 (got 14 columns instead of 13)
#     Line #409 (got 14 columns instead of 13)
#     Line #410 (got 14 columns instead of 13)
#     Line #411 (got 14 columns instead of 13)
#     Line #412 (got 14 columns instead of 13)
#     Line #413 (got 14 columns instead of 13)
#     Line #414 (got 14 columns instead of 13)
#     Line #415 (got 14 columns instead of 13)
#     Line #416 (got 14 columns instead of 13)
#     Line #417 (got 14 columns instead of 13)
#     Line #418 (got 14 columns instead of 13)
#     Line #419 (got 14 columns instead of 13)
#     Line #420 (got 14 columns instead of 13)
#     Line #421 (got 14 columns instead of 13)
#     Line #422 (got 14 columns instead of 13)
#     Line #423 (got 14 columns instead of 13)
#     Line #424 (got 14 columns instead of 13)
#     Line #425 (got 14 columns instead of 13)
#     Line #426 (got 14 columns instead of 13)
#     Line #427 (got 14 columns instead of 13)
#     Line #428 (got 14 columns instead of 13)
#     Line #429 (got 14 columns instead of 13)
#     Line #430 (got 14 columns instead of 13)
#     Line #431 (got 14 columns instead of 13)
#     Line #432 (got 14 columns instead of 13)
#     Line #433 (got 14 columns instead of 13)
#     Line #434 (got 14 columns instead of 13)
#     Line #435 (got 14 columns instead of 13)
#     Line #436 (got 14 columns instead of 13)
#     Line #437 (got 14 columns instead of 13)
#     Line #438 (got 14 columns instead of 13)
#     Line #439 (got 14 columns instead of 13)
#     Line #440 (got 14 columns instead of 13)
#     Line #441 (got 14 columns instead of 13)
#     Line #442 (got 14 columns instead of 13)
#     Line #443 (got 14 columns instead of 13)
#     Line #444 (got 14 columns instead of 13)
#     Line #445 (got 14 columns instead of 13)
#     Line #446 (got 14 columns instead of 13)
#     Line #447 (got 14 columns instead of 13)
#     Line #448 (got 14 columns instead of 13)
#     Line #449 (got 14 columns instead of 13)
#     Line #450 (got 14 columns instead of 13)
#     Line #451 (got 14 columns instead of 13)
#     Line #452 (got 14 columns instead of 13)
#     Line #453 (got 14 columns instead of 13)
#     Line #454 (got 14 columns instead of 13)
#     Line #455 (got 14 columns instead of 13)
#     Line #456 (got 14 columns instead of 13)
#     Line #457 (got 14 columns instead of 13)
#     Line #458 (got 14 columns instead of 13)
#     Line #459 (got 14 columns instead of 13)
#     Line #460 (got 14 columns instead of 13)
#     Line #461 (got 14 columns instead of 13)
#     Line #462 (got 14 columns instead of 13)
#     Line #463 (got 14 columns instead of 13)
#     Line #464 (got 14 columns instead of 13)
#     Line #465 (got 14 columns instead of 13)
#     Line #466 (got 14 columns instead of 13)
#     Line #467 (got 14 columns instead of 13)
#     Line #468 (got 14 columns instead of 13)
#     Line #469 (got 14 columns instead of 13)
#     Line #470 (got 14 columns instead of 13)
#     Line #471 (got 14 columns instead of 13)
#     Line #472 (got 14 columns instead of 13)
#     Line #473 (got 14 columns instead of 13)
#     Line #474 (got 14 columns instead of 13)
#     Line #475 (got 14 columns instead of 13)
#     Line #476 (got 14 columns instead of 13)
#     Line #477 (got 14 columns instead of 13)
#     Line #478 (got 14 columns instead of 13)
#     Line #479 (got 14 columns instead of 13)
#     Line #480 (got 14 columns instead of 13)
#     Line #481 (got 14 columns instead of 13)
#     Line #482 (got 14 columns instead of 13)
#     Line #483 (got 14 columns instead of 13)
#     Line #484 (got 14 columns instead of 13)
#     Line #485 (got 14 columns instead of 13)
#     Line #486 (got 14 columns instead of 13)
#     Line #487 (got 14 columns instead of 13)
#     Line #488 (got 14 columns instead of 13)
#     Line #489 (got 14 columns instead of 13)
#     Line #490 (got 14 columns instead of 13)
#     Line #491 (got 14 columns instead of 13)
#     Line #492 (got 14 columns instead of 13)
#     Line #493 (got 14 columns instead of 13)
#     Line #494 (got 14 columns instead of 13)
#     Line #495 (got 14 columns instead of 13)
#     Line #496 (got 14 columns instead of 13)
#     Line #497 (got 14 columns instead of 13)
#     Line #498 (got 14 columns instead of 13)
#     Line #499 (got 14 columns instead of 13)
#     Line #500 (got 14 columns instead of 13)
#     Line #501 (got 14 columns instead of 13)
#     Line #502 (got 14 columns instead of 13)
#     Line #503 (got 14 columns instead of 13)
#     Line #504 (got 14 columns instead of 13)
#     Line #505 (got 14 columns instead of 13)
#     Line #506 (got 14 columns instead of 13)
#     Line #507 (got 14 columns instead of 13)
#     Line #508 (got 14 columns instead of 13)
#     Line #509 (got 14 columns instead of 13)
#     Line #510 (got 14 columns instead of 13)
#     Line #511 (got 14 columns instead of 13)
#     Line #512 (got 14 columns instead of 13)
#     Line #513 (got 14 columns instead of 13)
#     Line #514 (got 14 columns instead of 13)
#     Line #515 (got 14 columns instead of 13)
#     Line #516 (got 14 columns instead of 13)
#     Line #517 (got 14 columns instead of 13)
#     Line #518 (got 14 columns instead of 13)
#     Line #519 (got 14 columns instead of 13)
#     Line #520 (got 14 columns instead of 13)
#     Line #521 (got 14 columns instead of 13)
#     Line #522 (got 14 columns instead of 13)
#     Line #523 (got 14 columns instead of 13)
#     Line #524 (got 14 columns instead of 13)
#     Line #525 (got 14 columns instead of 13)
#     Line #526 (got 14 columns instead of 13)
#     Line #527 (got 14 columns instead of 13)
#     Line #528 (got 14 columns instead of 13)
#     Line #529 (got 14 columns instead of 13)
#     Line #530 (got 14 columns instead of 13)
#     Line #531 (got 14 columns instead of 13)
#     Line #532 (got 14 columns instead of 13)
#     Line #533 (got 14 columns instead of 13)
#     Line #534 (got 14 columns instead of 13)
#     Line #535 (got 14 columns instead of 13)
#     Line #536 (got 14 columns instead of 13)
#     Line #537 (got 14 columns instead of 13)
#     Line #538 (got 14 columns instead of 13)
#     Line #539 (got 14 columns instead of 13)
#     Line #540 (got 14 columns instead of 13)
#     Line #541 (got 14 columns instead of 13)
#     Line #542 (got 14 columns instead of 13)
#     Line #543 (got 14 columns instead of 13)
#     Line #544 (got 14 columns instead of 13)
#     Line #545 (got 14 columns instead of 13)
#     Line #546 (got 14 columns instead of 13)
#     Line #547 (got 14 columns instead of 13)
#     Line #548 (got 14 columns instead of 13)
#     Line #549 (got 14 columns instead of 13)
#     Line #550 (got 14 columns instead of 13)
#     Line #551 (got 14 columns instead of 13)
#     Line #552 (got 14 columns instead of 13)
#     Line #553 (got 14 columns instead of 13)
#     Line #554 (got 14 columns instead of 13)
#     Line #555 (got 14 columns instead of 13)
#     Line #556 (got 14 columns instead of 13)
#     Line #557 (got 14 columns instead of 13)
#     Line #558 (got 14 columns instead of 13)
#     Line #559 (got 14 columns instead of 13)
#     Line #560 (got 14 columns instead of 13)
#     Line #561 (got 14 columns instead of 13)
#     Line #562 (got 14 columns instead of 13)
#     Line #563 (got 14 columns instead of 13)
#     Line #564 (got 14 columns instead of 13)
#     Line #565 (got 14 columns instead of 13)
#     Line #566 (got 14 columns instead of 13)
#     Line #567 (got 14 columns instead of 13)
#     Line #568 (got 14 columns instead of 13)
#     Line #569 (got 14 columns instead of 13)
#     Line #570 (got 14 columns instead of 13)
#     Line #571 (got 14 columns instead of 13)
#     Line #572 (got 14 columns instead of 13)
#     Line #573 (got 14 columns instead of 13)
#     Line #574 (got 14 columns instead of 13)
#     Line #575 (got 14 columns instead of 13)
#     Line #576 (got 14 columns instead of 13)
#     Line #577 (got 14 columns instead of 13)
#     Line #578 (got 14 columns instead of 13)
#     Line #579 (got 14 columns instead of 13)
#     Line #580 (got 14 columns instead of 13)
#     Line #581 (got 14 columns instead of 13)
#     Line #582 (got 14 columns instead of 13)
#     Line #583 (got 14 columns instead of 13)
#     Line #584 (got 14 columns instead of 13)
#     Line #585 (got 14 columns instead of 13)
#     Line #586 (got 14 columns instead of 13)
#     Line #587 (got 14 columns instead of 13)
#     Line #588 (got 14 columns instead of 13)
#     Line #589 (got 14 columns instead of 13)
#     Line #590 (got 14 columns instead of 13)
#     Line #591 (got 14 columns instead of 13)
#     Line #592 (got 14 columns instead of 13)
#     Line #593 (got 14 columns instead of 13)
#     Line #594 (got 14 columns instead of 13)
#     Line #595 (got 14 columns instead of 13)
#     Line #596 (got 14 columns instead of 13)
#     Line #597 (got 14 columns instead of 13)
#     Line #598 (got 14 columns instead of 13)
#     Line #599 (got 14 columns instead of 13)
#     Line #600 (got 14 columns instead of 13)
#     Line #601 (got 14 columns instead of 13)
#     Line #602 (got 14 columns instead of 13)
#     Line #603 (got 14 columns instead of 13)
#     Line #604 (got 14 columns instead of 13)
#     Line #605 (got 14 columns instead of 13)
#     Line #606 (got 14 columns instead of 13)
#     Line #607 (got 14 columns instead of 13)
#     Line #608 (got 14 columns instead of 13)
#     Line #609 (got 14 columns instead of 13)
#     Line #610 (got 14 columns instead of 13)
#     Line #611 (got 14 columns instead of 13)
#     Line #612 (got 14 columns instead of 13)
#     Line #613 (got 14 columns instead of 13)
#     Line #614 (got 14 columns instead of 13)
#     Line #615 (got 14 columns instead of 13)
#     Line #616 (got 14 columns instead of 13)
#     Line #617 (got 14 columns instead of 13)
#     Line #618 (got 14 columns instead of 13)
#     Line #619 (got 14 columns instead of 13)
#     Line #620 (got 14 columns instead of 13)
#     Line #621 (got 14 columns instead of 13)
#     Line #622 (got 14 columns instead of 13)
#     Line #623 (got 14 columns instead of 13)
#     Line #624 (got 14 columns instead of 13)
#     Line #625 (got 14 columns instead of 13)
#     Line #626 (got 14 columns instead of 13)
#     Line #627 (got 14 columns instead of 13)
#     Line #628 (got 14 columns instead of 13)
#     Line #629 (got 14 columns instead of 13)
#     Line #630 (got 14 columns instead of 13)
#     Line #631 (got 14 columns instead of 13)
#     Line #632 (got 14 columns instead of 13)
#     Line #633 (got 14 columns instead of 13)
#     Line #634 (got 14 columns instead of 13)
#     Line #635 (got 14 columns instead of 13)
#     Line #636 (got 14 columns instead of 13)
#     Line #637 (got 14 columns instead of 13)
#     Line #638 (got 14 columns instead of 13)
#     Line #639 (got 14 columns instead of 13)
#     Line #640 (got 14 columns instead of 13)
#     Line #641 (got 14 columns instead of 13)
#     Line #642 (got 14 columns instead of 13)
#     Line #643 (got 14 columns instead of 13)
#     Line #644 (got 14 columns instead of 13)
#     Line #645 (got 14 columns instead of 13)
#     Line #646 (got 14 columns instead of 13)
#     Line #647 (got 14 columns instead of 13)
#     Line #648 (got 14 columns instead of 13)
#     Line #649 (got 14 columns instead of 13)
#     Line #650 (got 14 columns instead of 13)
#     Line #651 (got 14 columns instead of 13)
#     Line #652 (got 14 columns instead of 13)
#     Line #653 (got 14 columns instead of 13)
#     Line #654 (got 14 columns instead of 13)
#     Line #655 (got 14 columns instead of 13)
#     Line #656 (got 14 columns instead of 13)
#     Line #657 (got 14 columns instead of 13)
#     Line #658 (got 14 columns instead of 13)
#     Line #659 (got 14 columns instead of 13)
#     Line #660 (got 14 columns instead of 13)
#     Line #661 (got 14 columns instead of 13)
#     Line #662 (got 14 columns instead of 13)
#     Line #663 (got 14 columns instead of 13)
#     Line #664 (got 14 columns instead of 13)
#     Line #665 (got 14 columns instead of 13)
#     Line #666 (got 14 columns instead of 13)
#     Line #667 (got 14 columns instead of 13)
#     Line #668 (got 14 columns instead of 13)
#     Line #669 (got 14 columns instead of 13)
#     Line #670 (got 14 columns instead of 13)
#     Line #671 (got 14 columns instead of 13)
#     Line #672 (got 14 columns instead of 13)
#     Line #673 (got 14 columns instead of 13)
#     Line #674 (got 14 columns instead of 13)
#     Line #675 (got 14 columns instead of 13)
#     Line #676 (got 14 columns instead of 13)
#     Line #677 (got 14 columns instead of 13)
#     Line #678 (got 14 columns instead of 13)
#     Line #679 (got 14 columns instead of 13)
#     Line #680 (got 14 columns instead of 13)
#     Line #681 (got 14 columns instead of 13)
#     Line #682 (got 14 columns instead of 13)
#     Line #683 (got 14 columns instead of 13)
#     Line #684 (got 14 columns instead of 13)
#     Line #685 (got 14 columns instead of 13)
#     Line #686 (got 14 columns instead of 13)
#     Line #687 (got 14 columns instead of 13)
#     Line #688 (got 14 columns instead of 13)
#     Line #689 (got 14 columns instead of 13)
#     Line #690 (got 14 columns instead of 13)
#     Line #691 (got 14 columns instead of 13)
#     Line #692 (got 14 columns instead of 13)
#     Line #693 (got 14 columns instead of 13)
#     Line #694 (got 14 columns instead of 13)
#     Line #695 (got 14 columns instead of 13)
#     Line #696 (got 14 columns instead of 13)
#     Line #697 (got 14 columns instead of 13)
#     Line #698 (got 14 columns instead of 13)
#     Line #699 (got 14 columns instead of 13)
#     Line #700 (got 14 columns instead of 13)
#     Line #701 (got 14 columns instead of 13)
#     Line #702 (got 14 columns instead of 13)
#     Line #703 (got 14 columns instead of 13)
#     Line #704 (got 14 columns instead of 13)
#     Line #705 (got 14 columns instead of 13)
#     Line #706 (got 14 columns instead of 13)
#     Line #707 (got 14 columns instead of 13)
#     Line #708 (got 14 columns instead of 13)
#     Line #709 (got 14 columns instead of 13)
#     Line #710 (got 14 columns instead of 13)
#     Line #711 (got 14 columns instead of 13)
#     Line #712 (got 14 columns instead of 13)
#     Line #713 (got 14 columns instead of 13)
#     Line #714 (got 14 columns instead of 13)
#     Line #715 (got 14 columns instead of 13)
#     Line #716 (got 14 columns instead of 13)
#     Line #717 (got 14 columns instead of 13)
#     Line #718 (got 14 columns instead of 13)
#     Line #719 (got 14 columns instead of 13)
#     Line #720 (got 14 columns instead of 13)
#     Line #721 (got 14 columns instead of 13)
#     Line #722 (got 14 columns instead of 13)
#     Line #723 (got 14 columns instead of 13)
#     Line #724 (got 14 columns instead of 13)
#     Line #725 (got 14 columns instead of 13)
#     Line #726 (got 14 columns instead of 13)
#     Line #727 (got 14 columns instead of 13)
#     Line #728 (got 14 columns instead of 13)
#     Line #729 (got 14 columns instead of 13)
#     Line #730 (got 14 columns instead of 13)
#     Line #731 (got 14 columns instead of 13)
#     Line #732 (got 14 columns instead of 13)
#     Line #733 (got 14 columns instead of 13)
#     Line #734 (got 14 columns instead of 13)
#     Line #735 (got 14 columns instead of 13)
#     Line #736 (got 14 columns instead of 13)
#     Line #737 (got 14 columns instead of 13)
#     Line #738 (got 14 columns instead of 13)
#     Line #739 (got 14 columns instead of 13)
#     Line #740 (got 14 columns instead of 13)
#     Line #741 (got 14 columns instead of 13)
#     Line #742 (got 14 columns instead of 13)
#     Line #743 (got 14 columns instead of 13)
#     Line #744 (got 14 columns instead of 13)
#     Line #745 (got 14 columns instead of 13)
#     Line #746 (got 14 columns instead of 13)
#     Line #747 (got 14 columns instead of 13)
#     Line #748 (got 14 columns instead of 13)
#     Line #749 (got 14 columns instead of 13)
#     Line #750 (got 14 columns instead of 13)
#     Line #751 (got 14 columns instead of 13)
#     Line #752 (got 14 columns instead of 13)
#     Line #753 (got 14 columns instead of 13)
#     Line #754 (got 14 columns instead of 13)
#     Line #755 (got 14 columns instead of 13)
#     Line #756 (got 14 columns instead of 13)
#     Line #757 (got 14 columns instead of 13)
#     Line #758 (got 14 columns instead of 13)
#     Line #759 (got 14 columns instead of 13)
#     Line #760 (got 14 columns instead of 13)
#     Line #761 (got 14 columns instead of 13)
#     Line #762 (got 14 columns instead of 13)
#     Line #763 (got 14 columns instead of 13)
#     Line #764 (got 14 columns instead of 13)
#     Line #765 (got 14 columns instead of 13)
#     Line #766 (got 14 columns instead of 13)
#     Line #767 (got 14 columns instead of 13)
#     Line #768 (got 14 columns instead of 13)
#     Line #769 (got 14 columns instead of 13)
#     Line #770 (got 14 columns instead of 13)
#     Line #771 (got 14 columns instead of 13)
#     Line #772 (got 14 columns instead of 13)
#     Line #773 (got 14 columns instead of 13)
#     Line #774 (got 14 columns instead of 13)
#     Line #775 (got 14 columns instead of 13)
#     Line #776 (got 14 columns instead of 13)
#     Line #777 (got 14 columns instead of 13)
#     Line #778 (got 14 columns instead of 13)
#     Line #779 (got 14 columns instead of 13)
#     Line #780 (got 14 columns instead of 13)
#     Line #781 (got 14 columns instead of 13)
#     Line #782 (got 14 columns instead of 13)
#     Line #783 (got 14 columns instead of 13)
#     Line #784 (got 14 columns instead of 13)
#     Line #785 (got 14 columns instead of 13)
#     Line #786 (got 14 columns instead of 13)
#     Line #787 (got 14 columns instead of 13)
#     Line #788 (got 14 columns instead of 13)
#     Line #789 (got 14 columns instead of 13)
#     Line #790 (got 14 columns instead of 13)
#     Line #791 (got 14 columns instead of 13)
#     Line #792 (got 14 columns instead of 13)
#     Line #793 (got 14 columns instead of 13)
#     Line #794 (got 14 columns instead of 13)
#     Line #795 (got 14 columns instead of 13)
#     Line #796 (got 14 columns instead of 13)
#     Line #797 (got 14 columns instead of 13)
#     Line #798 (got 14 columns instead of 13)
#     Line #799 (got 14 columns instead of 13)
#     Line #800 (got 14 columns instead of 13)
#     Line #801 (got 14 columns instead of 13)
#     Line #802 (got 14 columns instead of 13)
#     Line #803 (got 14 columns instead of 13)
#     Line #804 (got 14 columns instead of 13)
#     Line #805 (got 14 columns instead of 13)
#     Line #806 (got 14 columns instead of 13)
#     Line #807 (got 14 columns instead of 13)
#     Line #808 (got 14 columns instead of 13)
#     Line #809 (got 14 columns instead of 13)
#     Line #810 (got 14 columns instead of 13)
#     Line #811 (got 14 columns instead of 13)
#     Line #812 (got 14 columns instead of 13)
#     Line #813 (got 14 columns instead of 13)
#     Line #814 (got 14 columns instead of 13)
#     Line #815 (got 14 columns instead of 13)
#     Line #816 (got 14 columns instead of 13)
#     Line #817 (got 14 columns instead of 13)
#     Line #818 (got 14 columns instead of 13)
#     Line #819 (got 14 columns instead of 13)
#     Line #820 (got 14 columns instead of 13)
#     Line #821 (got 14 columns instead of 13)
#     Line #822 (got 14 columns instead of 13)
#     Line #823 (got 14 columns instead of 13)
#     Line #824 (got 14 columns instead of 13)
#     Line #825 (got 14 columns instead of 13)
#     Line #826 (got 14 columns instead of 13)
#     Line #827 (got 14 columns instead of 13)
#     Line #828 (got 14 columns instead of 13)
#     Line #829 (got 14 columns instead of 13)
#     Line #830 (got 14 columns instead of 13)
#     Line #831 (got 14 columns instead of 13)
#     Line #832 (got 14 columns instead of 13)
#     Line #833 (got 14 columns instead of 13)
#     Line #834 (got 14 columns instead of 13)
#     Line #835 (got 14 columns instead of 13)
#     Line #836 (got 14 columns instead of 13)
#     Line #837 (got 14 columns instead of 13)
#     Line #838 (got 14 columns instead of 13)
#     Line #839 (got 14 columns instead of 13)
#     Line #840 (got 14 columns instead of 13)
#     Line #841 (got 14 columns instead of 13)
#     Line #842 (got 14 columns instead of 13)
#     Line #843 (got 14 columns instead of 13)
#     Line #844 (got 14 columns instead of 13)
#     Line #845 (got 14 columns instead of 13)
#     Line #846 (got 14 columns instead of 13)
#     Line #847 (got 14 columns instead of 13)
#     Line #848 (got 14 columns instead of 13)
#     Line #849 (got 14 columns instead of 13)
#     Line #850 (got 14 columns instead of 13)
#     Line #851 (got 14 columns instead of 13)
#     Line #852 (got 14 columns instead of 13)
#     Line #853 (got 14 columns instead of 13)
#     Line #854 (got 14 columns instead of 13)
#     Line #855 (got 14 columns instead of 13)
#     Line #856 (got 14 columns instead of 13)
#     Line #857 (got 14 columns instead of 13)
#     Line #858 (got 14 columns instead of 13)
#     Line #859 (got 14 columns instead of 13)
#     Line #860 (got 14 columns instead of 13)
#     Line #861 (got 14 columns instead of 13)
#     Line #862 (got 14 columns instead of 13)
#     Line #863 (got 14 columns instead of 13)
#     Line #864 (got 14 columns instead of 13)
#     Line #865 (got 14 columns instead of 13)
#     Line #866 (got 14 columns instead of 13)
#     Line #867 (got 14 columns instead of 13)
#     Line #868 (got 14 columns instead of 13)
#     Line #869 (got 14 columns instead of 13)
#     Line #870 (got 14 columns instead of 13)
#     Line #871 (got 14 columns instead of 13)
#     Line #872 (got 14 columns instead of 13)
#     Line #873 (got 14 columns instead of 13)
#     Line #874 (got 14 columns instead of 13)
#     Line #875 (got 14 columns instead of 13)
#     Line #876 (got 14 columns instead of 13)
#     Line #877 (got 14 columns instead of 13)
#     Line #878 (got 14 columns instead of 13)
#     Line #879 (got 14 columns instead of 13)
#     Line #880 (got 14 columns instead of 13)
#     Line #881 (got 14 columns instead of 13)
#     Line #882 (got 14 columns instead of 13)
#     Line #883 (got 14 columns instead of 13)
#     Line #884 (got 14 columns instead of 13)
#     Line #885 (got 14 columns instead of 13)
#     Line #886 (got 14 columns instead of 13)
#     Line #887 (got 14 columns instead of 13)
#     Line #888 (got 14 columns instead of 13)
#     Line #889 (got 14 columns instead of 13)
#     Line #890 (got 14 columns instead of 13)
#     Line #891 (got 14 columns instead of 13)
#     Line #892 (got 14 columns instead of 13)

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived Pclass  \
# 0           0            1         0      3
# 1           1            2         1      1
# 2           2            3         1      3
# 3           3            4         1      1
# 4           4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Slicing DataFrames Using Conditional Logic
#
# One of the most common ways to query data with pandas is to simply slice the DataFrame so that the object returned contains only the data you're interested in.
#
# In the cell below, slice the DataFrame so that it only contains passengers with 2nd or 3rd class tickets (denoted by the `Pclass` column).
#
# **_Hint_**: Remember, your conditional logic must be passed into the slicing operator to return a slice of the DataFrame--otherwise, it will just return a table of boolean values based on the conditional statement!

# %%
no_first_class_df = df[df['Pclass'] != '1']
no_first_class_df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived Pclass                            Name  \
# 0           0            1         0      3         Braund, Mr. Owen Harris
# 2           2            3         1      3          Heikkinen, Miss. Laina
# 4           4            5         0      3        Allen, Mr. William Henry
# 5           5            6         0      3                Moran, Mr. James
# 7           7            8         0      3  Palsson, Master. Gosta Leonard
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
# 5    male   NaN      0      0            330877   8.4583   NaN        Q
# 7    male   2.0      3      1            349909  21.0750   NaN        S

# %% [markdown]
# We can also chain conditional statements together by wrapping them in parenthesis and making use of the `&` and `|` operators ('and' and 'or' operators, respectively).
#
# In the cell below, slice the DataFrame so that it only contains passengers with a `Fare` value between 50 and 100, inclusive.

# %%
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-51-060f5dd03f0f> in <module>()
# ----> 1 my_data = np.genfromtxt('titanic.csv', delimiter = ',')
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2073             # Raise an exception ?
#    2074             if invalid_raise:
# -> 2075                 raise ValueError(errmsg)
#    2076             # Issue a warning ?
#    2077             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 14 columns instead of 13)
#     Line #3 (got 14 columns instead of 13)
#     Line #4 (got 14 columns instead of 13)
#     Line #5 (got 14 columns instead of 13)
#     Line #6 (got 14 columns instead of 13)
#     Line #7 (got 14 columns instead of 13)
#     Line #8 (got 14 columns instead of 13)
#     Line #9 (got 14 columns instead of 13)
#     Line #10 (got 14 columns instead of 13)
#     Line #11 (got 14 columns instead of 13)
#     Line #12 (got 14 columns instead of 13)
#     Line #13 (got 14 columns instead of 13)
#     Line #14 (got 14 columns instead of 13)
#     Line #15 (got 14 columns instead of 13)
#     Line #16 (got 14 columns instead of 13)
#     Line #17 (got 14 columns instead of 13)
#     Line #18 (got 14 columns instead of 13)
#     Line #19 (got 14 columns instead of 13)
#     Line #20 (got 14 columns instead of 13)
#     Line #21 (got 14 columns instead of 13)
#     Line #22 (got 14 columns instead of 13)
#     Line #23 (got 14 columns instead of 13)
#     Line #24 (got 14 columns instead of 13)
#     Line #25 (got 14 columns instead of 13)
#     Line #26 (got 14 columns instead of 13)
#     Line #27 (got 14 columns instead of 13)
#     Line #28 (got 14 columns instead of 13)
#     Line #29 (got 14 columns instead of 13)
#     Line #30 (got 14 columns instead of 13)
#     Line #31 (got 14 columns instead of 13)
#     Line #32 (got 14 columns instead of 13)
#     Line #33 (got 14 columns instead of 13)
#     Line #34 (got 14 columns instead of 13)
#     Line #35 (got 14 columns instead of 13)
#     Line #36 (got 14 columns instead of 13)
#     Line #37 (got 14 columns instead of 13)
#     Line #38 (got 14 columns instead of 13)
#     Line #39 (got 14 columns instead of 13)
#     Line #40 (got 14 columns instead of 13)
#     Line #41 (got 14 columns instead of 13)
#     Line #42 (got 14 columns instead of 13)
#     Line #43 (got 14 columns instead of 13)
#     Line #44 (got 14 columns instead of 13)
#     Line #45 (got 14 columns instead of 13)
#     Line #46 (got 14 columns instead of 13)
#     Line #47 (got 14 columns instead of 13)
#     Line #48 (got 14 columns instead of 13)
#     Line #49 (got 14 columns instead of 13)
#     Line #50 (got 14 columns instead of 13)
#     Line #51 (got 14 columns instead of 13)
#     Line #52 (got 14 columns instead of 13)
#     Line #53 (got 14 columns instead of 13)
#     Line #54 (got 14 columns instead of 13)
#     Line #55 (got 14 columns instead of 13)
#     Line #56 (got 14 columns instead of 13)
#     Line #57 (got 14 columns instead of 13)
#     Line #58 (got 14 columns instead of 13)
#     Line #59 (got 14 columns instead of 13)
#     Line #60 (got 14 columns instead of 13)
#     Line #61 (got 14 columns instead of 13)
#     Line #62 (got 14 columns instead of 13)
#     Line #63 (got 14 columns instead of 13)
#     Line #64 (got 14 columns instead of 13)
#     Line #65 (got 14 columns instead of 13)
#     Line #66 (got 14 columns instead of 13)
#     Line #67 (got 14 columns instead of 13)
#     Line #68 (got 14 columns instead of 13)
#     Line #69 (got 14 columns instead of 13)
#     Line #70 (got 14 columns instead of 13)
#     Line #71 (got 14 columns instead of 13)
#     Line #72 (got 14 columns instead of 13)
#     Line #73 (got 14 columns instead of 13)
#     Line #74 (got 14 columns instead of 13)
#     Line #75 (got 14 columns instead of 13)
#     Line #76 (got 14 columns instead of 13)
#     Line #77 (got 14 columns instead of 13)
#     Line #78 (got 14 columns instead of 13)
#     Line #79 (got 14 columns instead of 13)
#     Line #80 (got 14 columns instead of 13)
#     Line #81 (got 14 columns instead of 13)
#     Line #82 (got 14 columns instead of 13)
#     Line #83 (got 14 columns instead of 13)
#     Line #84 (got 14 columns instead of 13)
#     Line #85 (got 14 columns instead of 13)
#     Line #86 (got 14 columns instead of 13)
#     Line #87 (got 14 columns instead of 13)
#     Line #88 (got 14 columns instead of 13)
#     Line #89 (got 14 columns instead of 13)
#     Line #90 (got 14 columns instead of 13)
#     Line #91 (got 14 columns instead of 13)
#     Line #92 (got 14 columns instead of 13)
#     Line #93 (got 14 columns instead of 13)
#     Line #94 (got 14 columns instead of 13)
#     Line #95 (got 14 columns instead of 13)
#     Line #96 (got 14 columns instead of 13)
#     Line #97 (got 14 columns instead of 13)
#     Line #98 (got 14 columns instead of 13)
#     Line #99 (got 14 columns instead of 13)
#     Line #100 (got 14 columns instead of 13)
#     Line #101 (got 14 columns instead of 13)
#     Line #102 (got 14 columns instead of 13)
#     Line #103 (got 14 columns instead of 13)
#     Line #104 (got 14 columns instead of 13)
#     Line #105 (got 14 columns instead of 13)
#     Line #106 (got 14 columns instead of 13)
#     Line #107 (got 14 columns instead of 13)
#     Line #108 (got 14 columns instead of 13)
#     Line #109 (got 14 columns instead of 13)
#     Line #110 (got 14 columns instead of 13)
#     Line #111 (got 14 columns instead of 13)
#     Line #112 (got 14 columns instead of 13)
#     Line #113 (got 14 columns instead of 13)
#     Line #114 (got 14 columns instead of 13)
#     Line #115 (got 14 columns instead of 13)
#     Line #116 (got 14 columns instead of 13)
#     Line #117 (got 14 columns instead of 13)
#     Line #118 (got 14 columns instead of 13)
#     Line #119 (got 14 columns instead of 13)
#     Line #120 (got 14 columns instead of 13)
#     Line #121 (got 14 columns instead of 13)
#     Line #122 (got 14 columns instead of 13)
#     Line #123 (got 14 columns instead of 13)
#     Line #124 (got 14 columns instead of 13)
#     Line #125 (got 14 columns instead of 13)
#     Line #126 (got 14 columns instead of 13)
#     Line #127 (got 14 columns instead of 13)
#     Line #128 (got 14 columns instead of 13)
#     Line #129 (got 14 columns instead of 13)
#     Line #130 (got 14 columns instead of 13)
#     Line #131 (got 14 columns instead of 13)
#     Line #132 (got 14 columns instead of 13)
#     Line #133 (got 14 columns instead of 13)
#     Line #134 (got 14 columns instead of 13)
#     Line #135 (got 14 columns instead of 13)
#     Line #136 (got 14 columns instead of 13)
#     Line #137 (got 14 columns instead of 13)
#     Line #138 (got 14 columns instead of 13)
#     Line #139 (got 14 columns instead of 13)
#     Line #140 (got 14 columns instead of 13)
#     Line #141 (got 14 columns instead of 13)
#     Line #142 (got 14 columns instead of 13)
#     Line #143 (got 14 columns instead of 13)
#     Line #144 (got 14 columns instead of 13)
#     Line #145 (got 14 columns instead of 13)
#     Line #146 (got 14 columns instead of 13)
#     Line #147 (got 14 columns instead of 13)
#     Line #148 (got 14 columns instead of 13)
#     Line #149 (got 14 columns instead of 13)
#     Line #150 (got 14 columns instead of 13)
#     Line #151 (got 14 columns instead of 13)
#     Line #152 (got 14 columns instead of 13)
#     Line #153 (got 14 columns instead of 13)
#     Line #154 (got 14 columns instead of 13)
#     Line #155 (got 14 columns instead of 13)
#     Line #156 (got 14 columns instead of 13)
#     Line #157 (got 14 columns instead of 13)
#     Line #158 (got 14 columns instead of 13)
#     Line #159 (got 14 columns instead of 13)
#     Line #160 (got 14 columns instead of 13)
#     Line #161 (got 14 columns instead of 13)
#     Line #162 (got 14 columns instead of 13)
#     Line #163 (got 14 columns instead of 13)
#     Line #164 (got 14 columns instead of 13)
#     Line #165 (got 14 columns instead of 13)
#     Line #166 (got 14 columns instead of 13)
#     Line #167 (got 14 columns instead of 13)
#     Line #168 (got 14 columns instead of 13)
#     Line #169 (got 14 columns instead of 13)
#     Line #170 (got 14 columns instead of 13)
#     Line #171 (got 14 columns instead of 13)
#     Line #172 (got 14 columns instead of 13)
#     Line #173 (got 14 columns instead of 13)
#     Line #174 (got 14 columns instead of 13)
#     Line #175 (got 14 columns instead of 13)
#     Line #176 (got 14 columns instead of 13)
#     Line #177 (got 14 columns instead of 13)
#     Line #178 (got 14 columns instead of 13)
#     Line #179 (got 14 columns instead of 13)
#     Line #180 (got 14 columns instead of 13)
#     Line #181 (got 14 columns instead of 13)
#     Line #182 (got 14 columns instead of 13)
#     Line #183 (got 14 columns instead of 13)
#     Line #184 (got 14 columns instead of 13)
#     Line #185 (got 14 columns instead of 13)
#     Line #186 (got 14 columns instead of 13)
#     Line #187 (got 14 columns instead of 13)
#     Line #188 (got 14 columns instead of 13)
#     Line #189 (got 14 columns instead of 13)
#     Line #190 (got 14 columns instead of 13)
#     Line #191 (got 14 columns instead of 13)
#     Line #192 (got 14 columns instead of 13)
#     Line #193 (got 14 columns instead of 13)
#     Line #194 (got 14 columns instead of 13)
#     Line #195 (got 14 columns instead of 13)
#     Line #196 (got 14 columns instead of 13)
#     Line #197 (got 14 columns instead of 13)
#     Line #198 (got 14 columns instead of 13)
#     Line #199 (got 14 columns instead of 13)
#     Line #200 (got 14 columns instead of 13)
#     Line #201 (got 14 columns instead of 13)
#     Line #202 (got 14 columns instead of 13)
#     Line #203 (got 14 columns instead of 13)
#     Line #204 (got 14 columns instead of 13)
#     Line #205 (got 14 columns instead of 13)
#     Line #206 (got 14 columns instead of 13)
#     Line #207 (got 14 columns instead of 13)
#     Line #208 (got 14 columns instead of 13)
#     Line #209 (got 14 columns instead of 13)
#     Line #210 (got 14 columns instead of 13)
#     Line #211 (got 14 columns instead of 13)
#     Line #212 (got 14 columns instead of 13)
#     Line #213 (got 14 columns instead of 13)
#     Line #214 (got 14 columns instead of 13)
#     Line #215 (got 14 columns instead of 13)
#     Line #216 (got 14 columns instead of 13)
#     Line #217 (got 14 columns instead of 13)
#     Line #218 (got 14 columns instead of 13)
#     Line #219 (got 14 columns instead of 13)
#     Line #220 (got 14 columns instead of 13)
#     Line #221 (got 14 columns instead of 13)
#     Line #222 (got 14 columns instead of 13)
#     Line #223 (got 14 columns instead of 13)
#     Line #224 (got 14 columns instead of 13)
#     Line #225 (got 14 columns instead of 13)
#     Line #226 (got 14 columns instead of 13)
#     Line #227 (got 14 columns instead of 13)
#     Line #228 (got 14 columns instead of 13)
#     Line #229 (got 14 columns instead of 13)
#     Line #230 (got 14 columns instead of 13)
#     Line #231 (got 14 columns instead of 13)
#     Line #232 (got 14 columns instead of 13)
#     Line #233 (got 14 columns instead of 13)
#     Line #234 (got 14 columns instead of 13)
#     Line #235 (got 14 columns instead of 13)
#     Line #236 (got 14 columns instead of 13)
#     Line #237 (got 14 columns instead of 13)
#     Line #238 (got 14 columns instead of 13)
#     Line #239 (got 14 columns instead of 13)
#     Line #240 (got 14 columns instead of 13)
#     Line #241 (got 14 columns instead of 13)
#     Line #242 (got 14 columns instead of 13)
#     Line #243 (got 14 columns instead of 13)
#     Line #244 (got 14 columns instead of 13)
#     Line #245 (got 14 columns instead of 13)
#     Line #246 (got 14 columns instead of 13)
#     Line #247 (got 14 columns instead of 13)
#     Line #248 (got 14 columns instead of 13)
#     Line #249 (got 14 columns instead of 13)
#     Line #250 (got 14 columns instead of 13)
#     Line #251 (got 14 columns instead of 13)
#     Line #252 (got 14 columns instead of 13)
#     Line #253 (got 14 columns instead of 13)
#     Line #254 (got 14 columns instead of 13)
#     Line #255 (got 14 columns instead of 13)
#     Line #256 (got 14 columns instead of 13)
#     Line #257 (got 14 columns instead of 13)
#     Line #258 (got 14 columns instead of 13)
#     Line #259 (got 14 columns instead of 13)
#     Line #260 (got 14 columns instead of 13)
#     Line #261 (got 14 columns instead of 13)
#     Line #262 (got 14 columns instead of 13)
#     Line #263 (got 14 columns instead of 13)
#     Line #264 (got 14 columns instead of 13)
#     Line #265 (got 14 columns instead of 13)
#     Line #266 (got 14 columns instead of 13)
#     Line #267 (got 14 columns instead of 13)
#     Line #268 (got 14 columns instead of 13)
#     Line #269 (got 14 columns instead of 13)
#     Line #270 (got 14 columns instead of 13)
#     Line #271 (got 14 columns instead of 13)
#     Line #272 (got 14 columns instead of 13)
#     Line #273 (got 14 columns instead of 13)
#     Line #274 (got 14 columns instead of 13)
#     Line #275 (got 14 columns instead of 13)
#     Line #276 (got 14 columns instead of 13)
#     Line #277 (got 14 columns instead of 13)
#     Line #278 (got 14 columns instead of 13)
#     Line #279 (got 14 columns instead of 13)
#     Line #280 (got 14 columns instead of 13)
#     Line #281 (got 14 columns instead of 13)
#     Line #282 (got 14 columns instead of 13)
#     Line #283 (got 14 columns instead of 13)
#     Line #284 (got 14 columns instead of 13)
#     Line #285 (got 14 columns instead of 13)
#     Line #286 (got 14 columns instead of 13)
#     Line #287 (got 14 columns instead of 13)
#     Line #288 (got 14 columns instead of 13)
#     Line #289 (got 14 columns instead of 13)
#     Line #290 (got 14 columns instead of 13)
#     Line #291 (got 14 columns instead of 13)
#     Line #292 (got 14 columns instead of 13)
#     Line #293 (got 14 columns instead of 13)
#     Line #294 (got 14 columns instead of 13)
#     Line #295 (got 14 columns instead of 13)
#     Line #296 (got 14 columns instead of 13)
#     Line #297 (got 14 columns instead of 13)
#     Line #298 (got 14 columns instead of 13)
#     Line #299 (got 14 columns instead of 13)
#     Line #300 (got 14 columns instead of 13)
#     Line #301 (got 14 columns instead of 13)
#     Line #302 (got 14 columns instead of 13)
#     Line #303 (got 14 columns instead of 13)
#     Line #304 (got 14 columns instead of 13)
#     Line #305 (got 14 columns instead of 13)
#     Line #306 (got 14 columns instead of 13)
#     Line #307 (got 14 columns instead of 13)
#     Line #308 (got 14 columns instead of 13)
#     Line #309 (got 14 columns instead of 13)
#     Line #310 (got 14 columns instead of 13)
#     Line #311 (got 14 columns instead of 13)
#     Line #312 (got 14 columns instead of 13)
#     Line #313 (got 14 columns instead of 13)
#     Line #314 (got 14 columns instead of 13)
#     Line #315 (got 14 columns instead of 13)
#     Line #316 (got 14 columns instead of 13)
#     Line #317 (got 14 columns instead of 13)
#     Line #318 (got 14 columns instead of 13)
#     Line #319 (got 14 columns instead of 13)
#     Line #320 (got 14 columns instead of 13)
#     Line #321 (got 14 columns instead of 13)
#     Line #322 (got 14 columns instead of 13)
#     Line #323 (got 14 columns instead of 13)
#     Line #324 (got 14 columns instead of 13)
#     Line #325 (got 14 columns instead of 13)
#     Line #326 (got 14 columns instead of 13)
#     Line #327 (got 14 columns instead of 13)
#     Line #328 (got 14 columns instead of 13)
#     Line #329 (got 14 columns instead of 13)
#     Line #330 (got 14 columns instead of 13)
#     Line #331 (got 14 columns instead of 13)
#     Line #332 (got 14 columns instead of 13)
#     Line #333 (got 14 columns instead of 13)
#     Line #334 (got 14 columns instead of 13)
#     Line #335 (got 14 columns instead of 13)
#     Line #336 (got 14 columns instead of 13)
#     Line #337 (got 14 columns instead of 13)
#     Line #338 (got 14 columns instead of 13)
#     Line #339 (got 14 columns instead of 13)
#     Line #340 (got 14 columns instead of 13)
#     Line #341 (got 14 columns instead of 13)
#     Line #342 (got 14 columns instead of 13)
#     Line #343 (got 14 columns instead of 13)
#     Line #344 (got 14 columns instead of 13)
#     Line #345 (got 14 columns instead of 13)
#     Line #346 (got 14 columns instead of 13)
#     Line #347 (got 14 columns instead of 13)
#     Line #348 (got 14 columns instead of 13)
#     Line #349 (got 14 columns instead of 13)
#     Line #350 (got 14 columns instead of 13)
#     Line #351 (got 14 columns instead of 13)
#     Line #352 (got 14 columns instead of 13)
#     Line #353 (got 14 columns instead of 13)
#     Line #354 (got 14 columns instead of 13)
#     Line #355 (got 14 columns instead of 13)
#     Line #356 (got 14 columns instead of 13)
#     Line #357 (got 14 columns instead of 13)
#     Line #358 (got 14 columns instead of 13)
#     Line #359 (got 14 columns instead of 13)
#     Line #360 (got 14 columns instead of 13)
#     Line #361 (got 14 columns instead of 13)
#     Line #362 (got 14 columns instead of 13)
#     Line #363 (got 14 columns instead of 13)
#     Line #364 (got 14 columns instead of 13)
#     Line #365 (got 14 columns instead of 13)
#     Line #366 (got 14 columns instead of 13)
#     Line #367 (got 14 columns instead of 13)
#     Line #368 (got 14 columns instead of 13)
#     Line #369 (got 14 columns instead of 13)
#     Line #370 (got 14 columns instead of 13)
#     Line #371 (got 14 columns instead of 13)
#     Line #372 (got 14 columns instead of 13)
#     Line #373 (got 14 columns instead of 13)
#     Line #374 (got 14 columns instead of 13)
#     Line #375 (got 14 columns instead of 13)
#     Line #376 (got 14 columns instead of 13)
#     Line #377 (got 14 columns instead of 13)
#     Line #378 (got 14 columns instead of 13)
#     Line #379 (got 14 columns instead of 13)
#     Line #380 (got 14 columns instead of 13)
#     Line #381 (got 14 columns instead of 13)
#     Line #382 (got 14 columns instead of 13)
#     Line #383 (got 14 columns instead of 13)
#     Line #384 (got 14 columns instead of 13)
#     Line #385 (got 14 columns instead of 13)
#     Line #386 (got 14 columns instead of 13)
#     Line #387 (got 14 columns instead of 13)
#     Line #388 (got 14 columns instead of 13)
#     Line #389 (got 14 columns instead of 13)
#     Line #390 (got 14 columns instead of 13)
#     Line #391 (got 14 columns instead of 13)
#     Line #392 (got 14 columns instead of 13)
#     Line #393 (got 14 columns instead of 13)
#     Line #394 (got 14 columns instead of 13)
#     Line #395 (got 14 columns instead of 13)
#     Line #396 (got 14 columns instead of 13)
#     Line #397 (got 14 columns instead of 13)
#     Line #398 (got 14 columns instead of 13)
#     Line #399 (got 14 columns instead of 13)
#     Line #400 (got 14 columns instead of 13)
#     Line #401 (got 14 columns instead of 13)
#     Line #402 (got 14 columns instead of 13)
#     Line #403 (got 14 columns instead of 13)
#     Line #404 (got 14 columns instead of 13)
#     Line #405 (got 14 columns instead of 13)
#     Line #406 (got 14 columns instead of 13)
#     Line #407 (got 14 columns instead of 13)
#     Line #408 (got 14 columns instead of 13)
#     Line #409 (got 14 columns instead of 13)
#     Line #410 (got 14 columns instead of 13)
#     Line #411 (got 14 columns instead of 13)
#     Line #412 (got 14 columns instead of 13)
#     Line #413 (got 14 columns instead of 13)
#     Line #414 (got 14 columns instead of 13)
#     Line #415 (got 14 columns instead of 13)
#     Line #416 (got 14 columns instead of 13)
#     Line #417 (got 14 columns instead of 13)
#     Line #418 (got 14 columns instead of 13)
#     Line #419 (got 14 columns instead of 13)
#     Line #420 (got 14 columns instead of 13)
#     Line #421 (got 14 columns instead of 13)
#     Line #422 (got 14 columns instead of 13)
#     Line #423 (got 14 columns instead of 13)
#     Line #424 (got 14 columns instead of 13)
#     Line #425 (got 14 columns instead of 13)
#     Line #426 (got 14 columns instead of 13)
#     Line #427 (got 14 columns instead of 13)
#     Line #428 (got 14 columns instead of 13)
#     Line #429 (got 14 columns instead of 13)
#     Line #430 (got 14 columns instead of 13)
#     Line #431 (got 14 columns instead of 13)
#     Line #432 (got 14 columns instead of 13)
#     Line #433 (got 14 columns instead of 13)
#     Line #434 (got 14 columns instead of 13)
#     Line #435 (got 14 columns instead of 13)
#     Line #436 (got 14 columns instead of 13)
#     Line #437 (got 14 columns instead of 13)
#     Line #438 (got 14 columns instead of 13)
#     Line #439 (got 14 columns instead of 13)
#     Line #440 (got 14 columns instead of 13)
#     Line #441 (got 14 columns instead of 13)
#     Line #442 (got 14 columns instead of 13)
#     Line #443 (got 14 columns instead of 13)
#     Line #444 (got 14 columns instead of 13)
#     Line #445 (got 14 columns instead of 13)
#     Line #446 (got 14 columns instead of 13)
#     Line #447 (got 14 columns instead of 13)
#     Line #448 (got 14 columns instead of 13)
#     Line #449 (got 14 columns instead of 13)
#     Line #450 (got 14 columns instead of 13)
#     Line #451 (got 14 columns instead of 13)
#     Line #452 (got 14 columns instead of 13)
#     Line #453 (got 14 columns instead of 13)
#     Line #454 (got 14 columns instead of 13)
#     Line #455 (got 14 columns instead of 13)
#     Line #456 (got 14 columns instead of 13)
#     Line #457 (got 14 columns instead of 13)
#     Line #458 (got 14 columns instead of 13)
#     Line #459 (got 14 columns instead of 13)
#     Line #460 (got 14 columns instead of 13)
#     Line #461 (got 14 columns instead of 13)
#     Line #462 (got 14 columns instead of 13)
#     Line #463 (got 14 columns instead of 13)
#     Line #464 (got 14 columns instead of 13)
#     Line #465 (got 14 columns instead of 13)
#     Line #466 (got 14 columns instead of 13)
#     Line #467 (got 14 columns instead of 13)
#     Line #468 (got 14 columns instead of 13)
#     Line #469 (got 14 columns instead of 13)
#     Line #470 (got 14 columns instead of 13)
#     Line #471 (got 14 columns instead of 13)
#     Line #472 (got 14 columns instead of 13)
#     Line #473 (got 14 columns instead of 13)
#     Line #474 (got 14 columns instead of 13)
#     Line #475 (got 14 columns instead of 13)
#     Line #476 (got 14 columns instead of 13)
#     Line #477 (got 14 columns instead of 13)
#     Line #478 (got 14 columns instead of 13)
#     Line #479 (got 14 columns instead of 13)
#     Line #480 (got 14 columns instead of 13)
#     Line #481 (got 14 columns instead of 13)
#     Line #482 (got 14 columns instead of 13)
#     Line #483 (got 14 columns instead of 13)
#     Line #484 (got 14 columns instead of 13)
#     Line #485 (got 14 columns instead of 13)
#     Line #486 (got 14 columns instead of 13)
#     Line #487 (got 14 columns instead of 13)
#     Line #488 (got 14 columns instead of 13)
#     Line #489 (got 14 columns instead of 13)
#     Line #490 (got 14 columns instead of 13)
#     Line #491 (got 14 columns instead of 13)
#     Line #492 (got 14 columns instead of 13)
#     Line #493 (got 14 columns instead of 13)
#     Line #494 (got 14 columns instead of 13)
#     Line #495 (got 14 columns instead of 13)
#     Line #496 (got 14 columns instead of 13)
#     Line #497 (got 14 columns instead of 13)
#     Line #498 (got 14 columns instead of 13)
#     Line #499 (got 14 columns instead of 13)
#     Line #500 (got 14 columns instead of 13)
#     Line #501 (got 14 columns instead of 13)
#     Line #502 (got 14 columns instead of 13)
#     Line #503 (got 14 columns instead of 13)
#     Line #504 (got 14 columns instead of 13)
#     Line #505 (got 14 columns instead of 13)
#     Line #506 (got 14 columns instead of 13)
#     Line #507 (got 14 columns instead of 13)
#     Line #508 (got 14 columns instead of 13)
#     Line #509 (got 14 columns instead of 13)
#     Line #510 (got 14 columns instead of 13)
#     Line #511 (got 14 columns instead of 13)
#     Line #512 (got 14 columns instead of 13)
#     Line #513 (got 14 columns instead of 13)
#     Line #514 (got 14 columns instead of 13)
#     Line #515 (got 14 columns instead of 13)
#     Line #516 (got 14 columns instead of 13)
#     Line #517 (got 14 columns instead of 13)
#     Line #518 (got 14 columns instead of 13)
#     Line #519 (got 14 columns instead of 13)
#     Line #520 (got 14 columns instead of 13)
#     Line #521 (got 14 columns instead of 13)
#     Line #522 (got 14 columns instead of 13)
#     Line #523 (got 14 columns instead of 13)
#     Line #524 (got 14 columns instead of 13)
#     Line #525 (got 14 columns instead of 13)
#     Line #526 (got 14 columns instead of 13)
#     Line #527 (got 14 columns instead of 13)
#     Line #528 (got 14 columns instead of 13)
#     Line #529 (got 14 columns instead of 13)
#     Line #530 (got 14 columns instead of 13)
#     Line #531 (got 14 columns instead of 13)
#     Line #532 (got 14 columns instead of 13)
#     Line #533 (got 14 columns instead of 13)
#     Line #534 (got 14 columns instead of 13)
#     Line #535 (got 14 columns instead of 13)
#     Line #536 (got 14 columns instead of 13)
#     Line #537 (got 14 columns instead of 13)
#     Line #538 (got 14 columns instead of 13)
#     Line #539 (got 14 columns instead of 13)
#     Line #540 (got 14 columns instead of 13)
#     Line #541 (got 14 columns instead of 13)
#     Line #542 (got 14 columns instead of 13)
#     Line #543 (got 14 columns instead of 13)
#     Line #544 (got 14 columns instead of 13)
#     Line #545 (got 14 columns instead of 13)
#     Line #546 (got 14 columns instead of 13)
#     Line #547 (got 14 columns instead of 13)
#     Line #548 (got 14 columns instead of 13)
#     Line #549 (got 14 columns instead of 13)
#     Line #550 (got 14 columns instead of 13)
#     Line #551 (got 14 columns instead of 13)
#     Line #552 (got 14 columns instead of 13)
#     Line #553 (got 14 columns instead of 13)
#     Line #554 (got 14 columns instead of 13)
#     Line #555 (got 14 columns instead of 13)
#     Line #556 (got 14 columns instead of 13)
#     Line #557 (got 14 columns instead of 13)
#     Line #558 (got 14 columns instead of 13)
#     Line #559 (got 14 columns instead of 13)
#     Line #560 (got 14 columns instead of 13)
#     Line #561 (got 14 columns instead of 13)
#     Line #562 (got 14 columns instead of 13)
#     Line #563 (got 14 columns instead of 13)
#     Line #564 (got 14 columns instead of 13)
#     Line #565 (got 14 columns instead of 13)
#     Line #566 (got 14 columns instead of 13)
#     Line #567 (got 14 columns instead of 13)
#     Line #568 (got 14 columns instead of 13)
#     Line #569 (got 14 columns instead of 13)
#     Line #570 (got 14 columns instead of 13)
#     Line #571 (got 14 columns instead of 13)
#     Line #572 (got 14 columns instead of 13)
#     Line #573 (got 14 columns instead of 13)
#     Line #574 (got 14 columns instead of 13)
#     Line #575 (got 14 columns instead of 13)
#     Line #576 (got 14 columns instead of 13)
#     Line #577 (got 14 columns instead of 13)
#     Line #578 (got 14 columns instead of 13)
#     Line #579 (got 14 columns instead of 13)
#     Line #580 (got 14 columns instead of 13)
#     Line #581 (got 14 columns instead of 13)
#     Line #582 (got 14 columns instead of 13)
#     Line #583 (got 14 columns instead of 13)
#     Line #584 (got 14 columns instead of 13)
#     Line #585 (got 14 columns instead of 13)
#     Line #586 (got 14 columns instead of 13)
#     Line #587 (got 14 columns instead of 13)
#     Line #588 (got 14 columns instead of 13)
#     Line #589 (got 14 columns instead of 13)
#     Line #590 (got 14 columns instead of 13)
#     Line #591 (got 14 columns instead of 13)
#     Line #592 (got 14 columns instead of 13)
#     Line #593 (got 14 columns instead of 13)
#     Line #594 (got 14 columns instead of 13)
#     Line #595 (got 14 columns instead of 13)
#     Line #596 (got 14 columns instead of 13)
#     Line #597 (got 14 columns instead of 13)
#     Line #598 (got 14 columns instead of 13)
#     Line #599 (got 14 columns instead of 13)
#     Line #600 (got 14 columns instead of 13)
#     Line #601 (got 14 columns instead of 13)
#     Line #602 (got 14 columns instead of 13)
#     Line #603 (got 14 columns instead of 13)
#     Line #604 (got 14 columns instead of 13)
#     Line #605 (got 14 columns instead of 13)
#     Line #606 (got 14 columns instead of 13)
#     Line #607 (got 14 columns instead of 13)
#     Line #608 (got 14 columns instead of 13)
#     Line #609 (got 14 columns instead of 13)
#     Line #610 (got 14 columns instead of 13)
#     Line #611 (got 14 columns instead of 13)
#     Line #612 (got 14 columns instead of 13)
#     Line #613 (got 14 columns instead of 13)
#     Line #614 (got 14 columns instead of 13)
#     Line #615 (got 14 columns instead of 13)
#     Line #616 (got 14 columns instead of 13)
#     Line #617 (got 14 columns instead of 13)
#     Line #618 (got 14 columns instead of 13)
#     Line #619 (got 14 columns instead of 13)
#     Line #620 (got 14 columns instead of 13)
#     Line #621 (got 14 columns instead of 13)
#     Line #622 (got 14 columns instead of 13)
#     Line #623 (got 14 columns instead of 13)
#     Line #624 (got 14 columns instead of 13)
#     Line #625 (got 14 columns instead of 13)
#     Line #626 (got 14 columns instead of 13)
#     Line #627 (got 14 columns instead of 13)
#     Line #628 (got 14 columns instead of 13)
#     Line #629 (got 14 columns instead of 13)
#     Line #630 (got 14 columns instead of 13)
#     Line #631 (got 14 columns instead of 13)
#     Line #632 (got 14 columns instead of 13)
#     Line #633 (got 14 columns instead of 13)
#     Line #634 (got 14 columns instead of 13)
#     Line #635 (got 14 columns instead of 13)
#     Line #636 (got 14 columns instead of 13)
#     Line #637 (got 14 columns instead of 13)
#     Line #638 (got 14 columns instead of 13)
#     Line #639 (got 14 columns instead of 13)
#     Line #640 (got 14 columns instead of 13)
#     Line #641 (got 14 columns instead of 13)
#     Line #642 (got 14 columns instead of 13)
#     Line #643 (got 14 columns instead of 13)
#     Line #644 (got 14 columns instead of 13)
#     Line #645 (got 14 columns instead of 13)
#     Line #646 (got 14 columns instead of 13)
#     Line #647 (got 14 columns instead of 13)
#     Line #648 (got 14 columns instead of 13)
#     Line #649 (got 14 columns instead of 13)
#     Line #650 (got 14 columns instead of 13)
#     Line #651 (got 14 columns instead of 13)
#     Line #652 (got 14 columns instead of 13)
#     Line #653 (got 14 columns instead of 13)
#     Line #654 (got 14 columns instead of 13)
#     Line #655 (got 14 columns instead of 13)
#     Line #656 (got 14 columns instead of 13)
#     Line #657 (got 14 columns instead of 13)
#     Line #658 (got 14 columns instead of 13)
#     Line #659 (got 14 columns instead of 13)
#     Line #660 (got 14 columns instead of 13)
#     Line #661 (got 14 columns instead of 13)
#     Line #662 (got 14 columns instead of 13)
#     Line #663 (got 14 columns instead of 13)
#     Line #664 (got 14 columns instead of 13)
#     Line #665 (got 14 columns instead of 13)
#     Line #666 (got 14 columns instead of 13)
#     Line #667 (got 14 columns instead of 13)
#     Line #668 (got 14 columns instead of 13)
#     Line #669 (got 14 columns instead of 13)
#     Line #670 (got 14 columns instead of 13)
#     Line #671 (got 14 columns instead of 13)
#     Line #672 (got 14 columns instead of 13)
#     Line #673 (got 14 columns instead of 13)
#     Line #674 (got 14 columns instead of 13)
#     Line #675 (got 14 columns instead of 13)
#     Line #676 (got 14 columns instead of 13)
#     Line #677 (got 14 columns instead of 13)
#     Line #678 (got 14 columns instead of 13)
#     Line #679 (got 14 columns instead of 13)
#     Line #680 (got 14 columns instead of 13)
#     Line #681 (got 14 columns instead of 13)
#     Line #682 (got 14 columns instead of 13)
#     Line #683 (got 14 columns instead of 13)
#     Line #684 (got 14 columns instead of 13)
#     Line #685 (got 14 columns instead of 13)
#     Line #686 (got 14 columns instead of 13)
#     Line #687 (got 14 columns instead of 13)
#     Line #688 (got 14 columns instead of 13)
#     Line #689 (got 14 columns instead of 13)
#     Line #690 (got 14 columns instead of 13)
#     Line #691 (got 14 columns instead of 13)
#     Line #692 (got 14 columns instead of 13)
#     Line #693 (got 14 columns instead of 13)
#     Line #694 (got 14 columns instead of 13)
#     Line #695 (got 14 columns instead of 13)
#     Line #696 (got 14 columns instead of 13)
#     Line #697 (got 14 columns instead of 13)
#     Line #698 (got 14 columns instead of 13)
#     Line #699 (got 14 columns instead of 13)
#     Line #700 (got 14 columns instead of 13)
#     Line #701 (got 14 columns instead of 13)
#     Line #702 (got 14 columns instead of 13)
#     Line #703 (got 14 columns instead of 13)
#     Line #704 (got 14 columns instead of 13)
#     Line #705 (got 14 columns instead of 13)
#     Line #706 (got 14 columns instead of 13)
#     Line #707 (got 14 columns instead of 13)
#     Line #708 (got 14 columns instead of 13)
#     Line #709 (got 14 columns instead of 13)
#     Line #710 (got 14 columns instead of 13)
#     Line #711 (got 14 columns instead of 13)
#     Line #712 (got 14 columns instead of 13)
#     Line #713 (got 14 columns instead of 13)
#     Line #714 (got 14 columns instead of 13)
#     Line #715 (got 14 columns instead of 13)
#     Line #716 (got 14 columns instead of 13)
#     Line #717 (got 14 columns instead of 13)
#     Line #718 (got 14 columns instead of 13)
#     Line #719 (got 14 columns instead of 13)
#     Line #720 (got 14 columns instead of 13)
#     Line #721 (got 14 columns instead of 13)
#     Line #722 (got 14 columns instead of 13)
#     Line #723 (got 14 columns instead of 13)
#     Line #724 (got 14 columns instead of 13)
#     Line #725 (got 14 columns instead of 13)
#     Line #726 (got 14 columns instead of 13)
#     Line #727 (got 14 columns instead of 13)
#     Line #728 (got 14 columns instead of 13)
#     Line #729 (got 14 columns instead of 13)
#     Line #730 (got 14 columns instead of 13)
#     Line #731 (got 14 columns instead of 13)
#     Line #732 (got 14 columns instead of 13)
#     Line #733 (got 14 columns instead of 13)
#     Line #734 (got 14 columns instead of 13)
#     Line #735 (got 14 columns instead of 13)
#     Line #736 (got 14 columns instead of 13)
#     Line #737 (got 14 columns instead of 13)
#     Line #738 (got 14 columns instead of 13)
#     Line #739 (got 14 columns instead of 13)
#     Line #740 (got 14 columns instead of 13)
#     Line #741 (got 14 columns instead of 13)
#     Line #742 (got 14 columns instead of 13)
#     Line #743 (got 14 columns instead of 13)
#     Line #744 (got 14 columns instead of 13)
#     Line #745 (got 14 columns instead of 13)
#     Line #746 (got 14 columns instead of 13)
#     Line #747 (got 14 columns instead of 13)
#     Line #748 (got 14 columns instead of 13)
#     Line #749 (got 14 columns instead of 13)
#     Line #750 (got 14 columns instead of 13)
#     Line #751 (got 14 columns instead of 13)
#     Line #752 (got 14 columns instead of 13)
#     Line #753 (got 14 columns instead of 13)
#     Line #754 (got 14 columns instead of 13)
#     Line #755 (got 14 columns instead of 13)
#     Line #756 (got 14 columns instead of 13)
#     Line #757 (got 14 columns instead of 13)
#     Line #758 (got 14 columns instead of 13)
#     Line #759 (got 14 columns instead of 13)
#     Line #760 (got 14 columns instead of 13)
#     Line #761 (got 14 columns instead of 13)
#     Line #762 (got 14 columns instead of 13)
#     Line #763 (got 14 columns instead of 13)
#     Line #764 (got 14 columns instead of 13)
#     Line #765 (got 14 columns instead of 13)
#     Line #766 (got 14 columns instead of 13)
#     Line #767 (got 14 columns instead of 13)
#     Line #768 (got 14 columns instead of 13)
#     Line #769 (got 14 columns instead of 13)
#     Line #770 (got 14 columns instead of 13)
#     Line #771 (got 14 columns instead of 13)
#     Line #772 (got 14 columns instead of 13)
#     Line #773 (got 14 columns instead of 13)
#     Line #774 (got 14 columns instead of 13)
#     Line #775 (got 14 columns instead of 13)
#     Line #776 (got 14 columns instead of 13)
#     Line #777 (got 14 columns instead of 13)
#     Line #778 (got 14 columns instead of 13)
#     Line #779 (got 14 columns instead of 13)
#     Line #780 (got 14 columns instead of 13)
#     Line #781 (got 14 columns instead of 13)
#     Line #782 (got 14 columns instead of 13)
#     Line #783 (got 14 columns instead of 13)
#     Line #784 (got 14 columns instead of 13)
#     Line #785 (got 14 columns instead of 13)
#     Line #786 (got 14 columns instead of 13)
#     Line #787 (got 14 columns instead of 13)
#     Line #788 (got 14 columns instead of 13)
#     Line #789 (got 14 columns instead of 13)
#     Line #790 (got 14 columns instead of 13)
#     Line #791 (got 14 columns instead of 13)
#     Line #792 (got 14 columns instead of 13)
#     Line #793 (got 14 columns instead of 13)
#     Line #794 (got 14 columns instead of 13)
#     Line #795 (got 14 columns instead of 13)
#     Line #796 (got 14 columns instead of 13)
#     Line #797 (got 14 columns instead of 13)
#     Line #798 (got 14 columns instead of 13)
#     Line #799 (got 14 columns instead of 13)
#     Line #800 (got 14 columns instead of 13)
#     Line #801 (got 14 columns instead of 13)
#     Line #802 (got 14 columns instead of 13)
#     Line #803 (got 14 columns instead of 13)
#     Line #804 (got 14 columns instead of 13)
#     Line #805 (got 14 columns instead of 13)
#     Line #806 (got 14 columns instead of 13)
#     Line #807 (got 14 columns instead of 13)
#     Line #808 (got 14 columns instead of 13)
#     Line #809 (got 14 columns instead of 13)
#     Line #810 (got 14 columns instead of 13)
#     Line #811 (got 14 columns instead of 13)
#     Line #812 (got 14 columns instead of 13)
#     Line #813 (got 14 columns instead of 13)
#     Line #814 (got 14 columns instead of 13)
#     Line #815 (got 14 columns instead of 13)
#     Line #816 (got 14 columns instead of 13)
#     Line #817 (got 14 columns instead of 13)
#     Line #818 (got 14 columns instead of 13)
#     Line #819 (got 14 columns instead of 13)
#     Line #820 (got 14 columns instead of 13)
#     Line #821 (got 14 columns instead of 13)
#     Line #822 (got 14 columns instead of 13)
#     Line #823 (got 14 columns instead of 13)
#     Line #824 (got 14 columns instead of 13)
#     Line #825 (got 14 columns instead of 13)
#     Line #826 (got 14 columns instead of 13)
#     Line #827 (got 14 columns instead of 13)
#     Line #828 (got 14 columns instead of 13)
#     Line #829 (got 14 columns instead of 13)
#     Line #830 (got 14 columns instead of 13)
#     Line #831 (got 14 columns instead of 13)
#     Line #832 (got 14 columns instead of 13)
#     Line #833 (got 14 columns instead of 13)
#     Line #834 (got 14 columns instead of 13)
#     Line #835 (got 14 columns instead of 13)
#     Line #836 (got 14 columns instead of 13)
#     Line #837 (got 14 columns instead of 13)
#     Line #838 (got 14 columns instead of 13)
#     Line #839 (got 14 columns instead of 13)
#     Line #840 (got 14 columns instead of 13)
#     Line #841 (got 14 columns instead of 13)
#     Line #842 (got 14 columns instead of 13)
#     Line #843 (got 14 columns instead of 13)
#     Line #844 (got 14 columns instead of 13)
#     Line #845 (got 14 columns instead of 13)
#     Line #846 (got 14 columns instead of 13)
#     Line #847 (got 14 columns instead of 13)
#     Line #848 (got 14 columns instead of 13)
#     Line #849 (got 14 columns instead of 13)
#     Line #850 (got 14 columns instead of 13)
#     Line #851 (got 14 columns instead of 13)
#     Line #852 (got 14 columns instead of 13)
#     Line #853 (got 14 columns instead of 13)
#     Line #854 (got 14 columns instead of 13)
#     Line #855 (got 14 columns instead of 13)
#     Line #856 (got 14 columns instead of 13)
#     Line #857 (got 14 columns instead of 13)
#     Line #858 (got 14 columns instead of 13)
#     Line #859 (got 14 columns instead of 13)
#     Line #860 (got 14 columns instead of 13)
#     Line #861 (got 14 columns instead of 13)
#     Line #862 (got 14 columns instead of 13)
#     Line #863 (got 14 columns instead of 13)
#     Line #864 (got 14 columns instead of 13)
#     Line #865 (got 14 columns instead of 13)
#     Line #866 (got 14 columns instead of 13)
#     Line #867 (got 14 columns instead of 13)
#     Line #868 (got 14 columns instead of 13)
#     Line #869 (got 14 columns instead of 13)
#     Line #870 (got 14 columns instead of 13)
#     Line #871 (got 14 columns instead of 13)
#     Line #872 (got 14 columns instead of 13)
#     Line #873 (got 14 columns instead of 13)
#     Line #874 (got 14 columns instead of 13)
#     Line #875 (got 14 columns instead of 13)
#     Line #876 (got 14 columns instead of 13)
#     Line #877 (got 14 columns instead of 13)
#     Line #878 (got 14 columns instead of 13)
#     Line #879 (got 14 columns instead of 13)
#     Line #880 (got 14 columns instead of 13)
#     Line #881 (got 14 columns instead of 13)
#     Line #882 (got 14 columns instead of 13)
#     Line #883 (got 14 columns instead of 13)
#     Line #884 (got 14 columns instead of 13)
#     Line #885 (got 14 columns instead of 13)
#     Line #886 (got 14 columns instead of 13)
#     Line #887 (got 14 columns instead of 13)
#     Line #888 (got 14 columns instead of 13)
#     Line #889 (got 14 columns instead of 13)
#     Line #890 (got 14 columns instead of 13)
#     Line #891 (got 14 columns instead of 13)
#     Line #892 (got 14 columns instead of 13)

# %%
fares_50_to_100_df = df.query()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-48-3b870100b178> in <module>()
# ----> 1 fares_50_to_100_df = df.query(int(df['Fare']) >= '50' & 'Fare' <= '100')
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %% [markdown]
# Remember that there are two syntactically correct ways to access a column in a DataFrame.  For instance, `df['Name']` and `df.Name` return the same thing.
#
# In the cell below, use the dot notation syntax and slice a DataFrame that contains male passengers that survived that also belong to Pclass 2 or 3.

# %%
poor_male_survivors_df = None

# %% [markdown]
# Great! Now that you've reviewed the methods for slicing a DataFrame for querying our data, let's explore a sample use case.
#
#
# ## Practical Example: Slicing DataFrames
#
# In this section, you're looking to investigate whether women and children survived more than men, or that rich passengers were more likely to survive than poor passengers.  The easiest way to confirm this is to slice the data into DataFrames that contain each subgroup, and then quickly visualize the survival rate of each subgroup with histograms.
#
# In the cell below, create a DataFrame that contains passengers that are female, as well as children (males included) under the age of 15 (exclusive).
#
# Additionally, create a DataFrame that contains only male passengers of all ages.

# %%
women_and_children_df = None
male_all_ages_df = None

# %% [markdown]
# Great! Now, you can use the `matplotlib` functionality built into the DataFrame objects to quickly create visualizations of the `Survived` column for each DataFrame.
#
# In the cell below, create histogram visualizations of the `Survived` column for both DataFrames.  Bonus points if you use `plt.title()` to label them correctly and make it easy to tell them apart!

# %% [markdown]
# Well that seems like a pretty stark difference--it seems that there was drastically different behavior between the groups!  Now, let's repeat the same process, but separating rich and poor passengers.
#
# In the cell below, create one DataFrame containing Fist Class passengers (`Pclass == 1`), and another DataFrame containing everyone else.

# %%
first_class_df = None
second_third_class_df = None

# %% [markdown]
# Now, create histograms of the surivival for each subgroup, just as you did above.

# %% [markdown]
# To the surprise of absolutely no one, it seems like First Class passengers were more likely to survive than not, while 2nd and 3rd class passengers were more likely to die than not.  However, don't read too far into these graphs, as these aren't at the same scale, so they aren't fair comparisons.
#
# Slicing is a useful method for quickly getting DataFrames that contain only the examples we're looking for.  It's a quick, easy method that feels intuitive in Python, since we can rely on the same conditional logic that we would if we were just writing `if/else` statements.

# %% [markdown]
# ## Using the `.query()` method
#
# Instead of slicing, you can also make use of the DataFrame's built-in `.query()` method.  This method reads a bit cleaner, and allows us to pass in our arguments as a string.  For more information or example code on how to use this method, see the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.query.html).
#
# In the cell below, use the `.query()` method to slice a DataFrame that contains only passengers who have a `PassengerId` greater than or equal to 500.

# %%
query_string = None
high_passenger_number_df = None
# high_passenger_number_df.head()

# %% [markdown]
# Just as with slicing, you can pass in queries with multiple conditions.  One unique difference between using the `.query()` method and conditional slicing is that you can use `and` or `&` as well as `or` or `|` (for fun, try reading this last sentence out loud), while you are limited to the `&` and `|` symbols to denote and/or operations with conditional slicing.
#
# In the cell below, use the `query()` method to return a DataFrame that contains only female passengers under the age of 15 (exclusive).
#
# **_Hint_**: Although the entire query is a string, you'll still need to denote that `female` is also a string, within the string.  (String-Ception?)

# %%
female_children_df = None
# female_children_df.head()

# %% [markdown]
# A cousin of the `query()` method, `eval()` allows you to use the same string-filled syntax as querying for creating new columns.  For instance:
#
# ```
# some_df.eval('C = A + B')
# ```
#
# would return a copy of the `some_df` dataframe, but will now include a column `C` where all values are equal to the sum of the `A` and `B` values for any given row.  This method also allows the user to specify if the operation should be done in place or not, providing a quick, easy syntax for simple feature engineering.
#
# In the cell below, use the DataFrame's `eval()` method in place to add a column called `Age_x_Fare`, and set it equal to `Age` multiplied by `Fare`.

# %%
# df.head()

# %% [markdown]
# Great! Now, let's move on the coolest part of this lab--querying DataFrames with SQL!
#
# ## Querying DataFrames With SQL

# %% [markdown]
# For the final section of the lab, you'll make use of the `pandasql` library.  Pandasql is a library designed to make it easy to query DataFrames directly with SQL syntax, which was open-sourced by the company Yhat in late 2016.  It's very straightforward to use, but you are still encouraged to take a look at the [documentation](https://github.com/yhat/pandasql) as needed.
#
# If you're using the prebuilt virtual environment, you should already have the package ready to import. If not, run the cell below to pip install pandasql so that it is available to import.

# %%
# !pip install pandasql

# %% [markdown]
# That should have installed everything correctly. This library has a few dependencies, which you should already have installed. If you don't, just `pip install` them in your terminal and you'll be good to go!
#
# In the cell below, import `sqldf` from `pandasql`.

# %% [markdown]
# Great! Now, it's time get some practice with this handy library.
#
# `pandasql` allows you to pass in SQL queries in the form of a string to directly query our database.  Each time you make a query, you need pass an additional parameter that gives it access to the other variables in the session/environment. You can use a lambda function to pass `locals()` or `globals()` so that you don't have to type this every time.
#
# In the cell below, create a variable called `pysqldf` and set it equal to a lambda function `q` that returns `sqldf(q, globals())`.  If you're unsure of how to do this, see the example in the [documentation](https://github.com/yhat/pandasql).

# %%
pysqldf = None

# %% [markdown]
# Great! That will save you from having to pass `globals()` as an argument every time you query, which can get a bit tedious.
#
# Now write a basic query to get a list of passenger names from `df`, limit 10.  If you would prefer to format your query on multiple lines and style it as canonical SQL, that's fine--remember that multi-line strings in python are denoted by `"""`--for example:
# ```
# """
# This is a
# Multi-Line String
# """
# ```
#
# In the cell below, write a SQL query that returns the names of the first 10 passengers.

# %%
q = None

passenger_names = None
passenger_names

# %% [markdown]
# Great! Now, for a harder one:
#
# In the cell below, query the DataFrame for names and fares of any male passengers that survived, limit 30.

# %%
q2 = None

sql_surviving_males = None
sql_surviving_males

# %% [markdown]
# This library is really powerful! This makes it easy for us to leverage all of SQL knowledge to quickly query any DataFrame, especially when you only want to select certain columns.  This saves from having to slice/query the DataFrame and then slice the columns you want (or drop the ones you don't want).
#
# Although it's outside the scope of this lab, it's also worth noting that both `pandas` and `pandasql` provide built-in functionality for join operations, too!
#
#
# ## Practical Example: SQL in Pandas
#
# In the cell below, create 2 separate DataFrames using `pandasql`.  One should contain the Pclass of all female passengers that survived, and the other should contain the Pclass of all female passengers that died.
#
# Then, create histogram visualizations of the `Pclass` column for each DataFrame to compare the two.  Bonus points for taking the time to make the graphs extra readable by adding titles, labeling each axis, and cleaning up the number of ticks on the X-axis!

# %%
# Write your queries in these variables to keep your code well-formatted and readable
q3 = None
q4 = None

survived_females_by_pclass_df = None
died_females_by_pclass_df = None

# Create and label the histograms for each below!

# %% [markdown]
# ## Summary
#
# In this lab, you practiced how to query Pandas DataFrames using SQL.
